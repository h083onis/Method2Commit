# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import os
import numpy as np
import pandas as pd

ctxt_df = pd.read_csv("../data/camel_filtered_data_ctxt_vecs.csv", header=0)
df = pd.read_csv("../data/camel_filtered_data_vecs2.csv", header=0)

# %%
ctxt_df[ctxt_df['commit_id'] == "a4701ac4bf5b50810914796e284b0e3f78a240bc"]
# Out:
#                                   commit_id  \
# 0  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 1  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 2  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 3  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 4  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 5  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 6  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 7  a4701ac4bf5b50810914796e284b0e3f78a240bc
#
#                                              snippet  \
# 0  public static <E> Predicate<E> and(final Predi...
# 1  public static <E> Predicate<E> or(final Predic...
# 2  public ProcessorBuilder<E> to(Endpoint<E> endp...
# 3  public Processor<E> createProcessor() {\n     ...
# 4  public Predicate<E> getPredicate() {\n        ...
# 5  public Predicate<E> headerEquals(final String ...
# 6  protected void checkInitialized() {\n        i...
# 7  public DestinationBuilder<E> from(Endpoint<E> ...
#
#                                                  ast  is_defect  kinds  \
# ...

# %%
df[df['commit_id'] == "a4701ac4bf5b50810914796e284b0e3f78a240bc"]
# Out:
#                                   commit_id  \
# 0  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 1  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 2  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 3  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 4  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 5  a4701ac4bf5b50810914796e284b0e3f78a240bc
#
#                                              snippet  is_defect  kinds  \
# 0  public static <E> Predicate<E> or(final Predic...       True  train
# 1  public static <E> Predicate<E> and(final Predi...       True  train
# 2  public ProcessorBuilder<E> to(Endpoint<E> endp...       True  train
# 3  public Predicate<E> headerEquals(final String ...       True  train
# 4  public DestinationBuilder<E> from(Endpoint<E> ...       True  train
# 5  protected void checkInitialized() {\n        i...       True  train
#
#                                          snippet_vec        ns        nd  \
# 0  [-0.00199335184879601, -0.0005455845384858549,...  0.244651  0.229564
# ...

# %%
ctxt_df2.head()
# Out:
#                                   commit_id  \
# 0  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 1  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 2  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 3  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 4  a4701ac4bf5b50810914796e284b0e3f78a240bc
#
#                                              snippet  is_defect  kinds  \
# 0  public static <E> Predicate<E> or(final Predic...       True  train
# 1  public static <E> Predicate<E> and(final Predi...       True  train
# 2  public ProcessorBuilder<E> to(Endpoint<E> endp...       True  train
# 3              public boolean evaluate(E exchange...       True  train
# 4  public DestinationBuilder<E> from(Endpoint<E> ...       True  train
#
#                                          snippet_vec        ns        nd  \
# 0  [0.00045764894457533956, 0.00783359631896019, ...  0.244651  0.229564
# 1  [-0.035060685127973557, -0.0007980534574016929...  0.244651  0.229564
# ...

# %%
print(ctxt_df.iloc[0]['snippet'])
print(ctxt_df2.iloc[1]['snippet'])
# Out:
# public static <E> Predicate<E> and(final Predicate<E> left, final Predicate<E> right) {
#         notNull(left, "left");
#         notNull(right, "right");
#         return new Predicate<E>() {
#             public boolean evaluate(E exchange) {
#                 return left.evaluate(exchange) && right.evaluate(exchange);
#             }
#         };
#     } </s> public static <E> Predicate<E> and(final Predicate<E> left, final Predicate<E> right) {
#         ObjectHelper.notNull(left, "left");
#         ObjectHelper.notNull(right, "right");
#         return new Predicate<E>() {
#             public boolean evaluate(E exchange) {
#                 return left.evaluate(exchange) && right.evaluate(exchange);
#             }
#         };
#     }
# ...

# %%
df2 = pd.read_csv("../data/camel_filtered_data2.csv", header=0)
df2.head()
# Out:
#                                   commit_id  \
# 0  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 1  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 2  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 3  a4701ac4bf5b50810914796e284b0e3f78a240bc
# 4  a4701ac4bf5b50810914796e284b0e3f78a240bc
#
#                                              snippet  is_defect  kinds
# 0  public static <E> Predicate<E> or(final Predic...       True  train
# 1  public static <E> Predicate<E> and(final Predi...       True  train
# 2  public ProcessorBuilder<E> to(Endpoint<E> endp...       True  train
# 3  public Predicate<E> headerEquals(final String ...       True  train
# 4  public DestinationBuilder<E> from(Endpoint<E> ...       True  train
